# %% [markdown]
# # Inserindo dados no MongoDB

# %%
from pymongo import MongoClient #Conexão com MongoDB
import pprint #Mostrar informações dos dados do banco de dados
import pandas as pd #Leitura dos arquivos
from pymongo import timeout
import numpy as np

# %% [markdown]
# ## Criando o cliente do MongoDB

# %%
client = MongoClient('localhost', 27017)

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
#Nome do banco de dados
nome_bd = 'Sales-Forecasting_'

# %%
db = client[nome_bd]

# %% [markdown]
# ## Lendo os arquivos .csv

# %%
#Pega o nome dos arquivos e remove o .csv deles
import os

mylist = os.listdir("datasets")
dic_files = {}
for file in mylist:
    if not file.startswith("test"):
        aux = file.split(".")[0]
        dic_files[aux] = pd.read_csv(f"datasets/{file}")
# Out:
# /tmp/ipykernel_4998/3272867525.py:9: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dic_files[aux] = pd.read_csv(f"datasets/{file}")

# %%
# Total de datasets
len(dic_files)
# Out:
# 2

# %% [markdown]
# ## Removendo arquivos vazios

# %%
# Verificando se todos os datasets tem mais de 0 instâncias

final_dic = dic_files.copy()
for i in dic_files:

    if dic_files[i].shape[0] == 0:
        del final_dic[i]

# %%
# Total de datasets
len(final_dic)
# Out:
# 2

# %% [markdown]
# ## Visualizando informações dos conjuntos

# %%
# Cabeçalho de um conjunto de dados
final_dic['train'].head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Formato do conjunto de dados
final_dic['train'].shape
# Out:
# (1017209, 9)

# %%
# Colunas dos nossos conjuntos de dados
final_dic['train'].columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
# Tipos dos nosso valores
final_dic['train'].dtypes
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %%
# Verificando valores NULOS
final_dic['train'].isna().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
# Cabeçalho de um conjunto de dados
final_dic['store'].head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
# Formato do conjunto de dados
final_dic['store'].shape
# Out:
# (1115, 10)

# %%
# Colunas dos nossos conjuntos de dados
final_dic['store'].columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
# Tipos dos nosso valores
final_dic['store'].dtypes
# Out:
# Store                          int64
# StoreType                     object
# Assortment                    object
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %%
# Verificando valores NULOS
final_dic['store'].isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# ## Tratando valores NULOS

# %%
# Vamos verificar quais os atributos contém valores nulos nos datasets
for i in list(final_dic.keys()):
    print(list((final_dic[i].isna().sum() > 0).where((final_dic[i].isna().sum()>0)).dropna().keys()))
# Out:
# []
# ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']

# %% [markdown]
# Os seguintes atributos tem pelo menos um valor NULO no conjunto de dados de store:  ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'].
#
# E devido a isso, iremos apenas remover estes atributos, já que não usaremos eles futuramente.

# %%
final_dic['store']['CompetitionDistance'].max()
# Out:
# 75860.0

# %%
final_dic['store'].loc[final_dic['store']['CompetitionDistance'].isna(),'CompetitionDistance'] = int(1e5)

# %%
final_dic['store'].dropna(axis=1,inplace=True)

# %%
# Vamos verificar quais os atributos contém valores nulos nos datasets
for i in list(final_dic.keys()):
    print(list((final_dic[i].isna().sum() > 0).where((final_dic[i].isna().sum()>0)).dropna().keys()))
# Out:
# []
# []

# %% [markdown]
# Tratamos os valores NULOS, agora podemos lidar com outros processamentos. Mas antes vamos inserir as lojas no nosso conjunto de dados.

# %% [markdown]
# ## Inserindo as lojas no Mongo

# %%
final_dic['store'].head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  Promo2
# 0      1         c          a               1270.0       0
# 1      2         a          a                570.0       1
# 2      3         a          a              14130.0       1
# 3      4         c          c                620.0       0
# 4      5         a          a              29910.0       0

# %%
stores = db.Stores
stores
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Sales-Forecasting'), 'Stores')

# %%
main_fdata = []

columns = final_dic['store'].columns

rows,cols = final_dic['store'].shape

for index, row in final_dic['store'].iterrows():
        fdata = {}
        for i in range(cols):
                fdata[columns[i]] = row[columns[i]]
        main_fdata.append(fdata)

with timeout(100):
    stores.insert_many(main_fdata)

# %%
for post in stores.find({}):
    pprint.pprint(post)
# Out:
# {'Assortment': 'a',
#  'CompetitionDistance': 1270.0,
#  'Promo2': 0,
#  'Store': 1,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe01f7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 570.0,
#  'Promo2': 1,
#  'Store': 2,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01f8')}
# {'Assortment': 'a',
#  'CompetitionDistance': 14130.0,
#  'Promo2': 1,
#  'Store': 3,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01f9')}
# {'Assortment': 'c',
#  'CompetitionDistance': 620.0,
#  'Promo2': 0,
#  'Store': 4,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe01fa')}
# {'Assortment': 'a',
#  'CompetitionDistance': 29910.0,
#  'Promo2': 0,
#  'Store': 5,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01fb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 310.0,
#  'Promo2': 0,
#  'Store': 6,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01fc')}
# {'Assortment': 'c',
#  'CompetitionDistance': 24000.0,
#  'Promo2': 0,
#  'Store': 7,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01fd')}
# {'Assortment': 'a',
#  'CompetitionDistance': 7520.0,
#  'Promo2': 0,
#  'Store': 8,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01fe')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2030.0,
#  'Promo2': 0,
#  'Store': 9,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe01ff')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3160.0,
#  'Promo2': 0,
#  'Store': 10,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0200')}
# {'Assortment': 'c',
#  'CompetitionDistance': 960.0,
#  'Promo2': 1,
#  'Store': 11,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0201')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1070.0,
#  'Promo2': 1,
#  'Store': 12,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0202')}
# {'Assortment': 'a',
#  'CompetitionDistance': 310.0,
#  'Promo2': 1,
#  'Store': 13,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0203')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1300.0,
#  'Promo2': 1,
#  'Store': 14,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0204')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4110.0,
#  'Promo2': 1,
#  'Store': 15,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0205')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3270.0,
#  'Promo2': 0,
#  'Store': 16,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0206')}
# {'Assortment': 'a',
#  'CompetitionDistance': 50.0,
#  'Promo2': 1,
#  'Store': 17,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0207')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13840.0,
#  'Promo2': 1,
#  'Store': 18,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0208')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3240.0,
#  'Promo2': 1,
#  'Store': 19,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0209')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2340.0,
#  'Promo2': 1,
#  'Store': 20,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe020a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 550.0,
#  'Promo2': 1,
#  'Store': 21,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe020b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1040.0,
#  'Promo2': 1,
#  'Store': 22,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe020c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4060.0,
#  'Promo2': 0,
#  'Store': 23,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe020d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4590.0,
#  'Promo2': 1,
#  'Store': 24,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe020e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 430.0,
#  'Promo2': 0,
#  'Store': 25,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe020f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2300.0,
#  'Promo2': 0,
#  'Store': 26,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0210')}
# {'Assortment': 'a',
#  'CompetitionDistance': 60.0,
#  'Promo2': 1,
#  'Store': 27,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0211')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1200.0,
#  'Promo2': 1,
#  'Store': 28,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0212')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2170.0,
#  'Promo2': 0,
#  'Store': 29,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0213')}
# {'Assortment': 'a',
#  'CompetitionDistance': 40.0,
#  'Promo2': 1,
#  'Store': 30,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0214')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9800.0,
#  'Promo2': 0,
#  'Store': 31,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0215')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2910.0,
#  'Promo2': 1,
#  'Store': 32,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0216')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1320.0,
#  'Promo2': 0,
#  'Store': 33,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0217')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2240.0,
#  'Promo2': 0,
#  'Store': 34,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0218')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7660.0,
#  'Promo2': 1,
#  'Store': 35,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0219')}
# {'Assortment': 'c',
#  'CompetitionDistance': 540.0,
#  'Promo2': 1,
#  'Store': 36,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe021a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4230.0,
#  'Promo2': 0,
#  'Store': 37,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe021b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1090.0,
#  'Promo2': 0,
#  'Store': 38,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe021c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 260.0,
#  'Promo2': 1,
#  'Store': 39,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe021d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 180.0,
#  'Promo2': 1,
#  'Store': 40,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe021e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1180.0,
#  'Promo2': 1,
#  'Store': 41,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe021f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 290.0,
#  'Promo2': 1,
#  'Store': 42,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0220')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4880.0,
#  'Promo2': 1,
#  'Store': 43,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0221')}
# {'Assortment': 'a',
#  'CompetitionDistance': 540.0,
#  'Promo2': 0,
#  'Store': 44,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0222')}
# {'Assortment': 'a',
#  'CompetitionDistance': 9710.0,
#  'Promo2': 0,
#  'Store': 45,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0223')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1200.0,
#  'Promo2': 1,
#  'Store': 46,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0224')}
# {'Assortment': 'c',
#  'CompetitionDistance': 270.0,
#  'Promo2': 1,
#  'Store': 47,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0225')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1060.0,
#  'Promo2': 0,
#  'Store': 48,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0226')}
# {'Assortment': 'c',
#  'CompetitionDistance': 18010.0,
#  'Promo2': 0,
#  'Store': 49,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0227')}
# {'Assortment': 'a',
#  'CompetitionDistance': 6260.0,
#  'Promo2': 0,
#  'Store': 50,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0228')}
# {'Assortment': 'c',
#  'CompetitionDistance': 10570.0,
#  'Promo2': 1,
#  'Store': 51,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0229')}
# {'Assortment': 'c',
#  'CompetitionDistance': 450.0,
#  'Promo2': 1,
#  'Store': 52,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe022a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 30360.0,
#  'Promo2': 0,
#  'Store': 53,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe022b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7170.0,
#  'Promo2': 1,
#  'Store': 54,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe022c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 720.0,
#  'Promo2': 0,
#  'Store': 55,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe022d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6620.0,
#  'Promo2': 1,
#  'Store': 56,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe022e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 420.0,
#  'Promo2': 0,
#  'Store': 57,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe022f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7340.0,
#  'Promo2': 1,
#  'Store': 58,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0230')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2840.0,
#  'Promo2': 1,
#  'Store': 59,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0231')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5540.0,
#  'Promo2': 0,
#  'Store': 60,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0232')}
# {'Assortment': 'c',
#  'CompetitionDistance': 350.0,
#  'Promo2': 1,
#  'Store': 61,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0233')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2050.0,
#  'Promo2': 0,
#  'Store': 62,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0234')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3700.0,
#  'Promo2': 1,
#  'Store': 63,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0235')}
# {'Assortment': 'c',
#  'CompetitionDistance': 22560.0,
#  'Promo2': 1,
#  'Store': 64,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0236')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13840.0,
#  'Promo2': 1,
#  'Store': 65,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0237')}
# {'Assortment': 'a',
#  'CompetitionDistance': 7660.0,
#  'Promo2': 1,
#  'Store': 66,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0238')}
# {'Assortment': 'c',
#  'CompetitionDistance': 410.0,
#  'Promo2': 0,
#  'Store': 67,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0239')}
# {'Assortment': 'c',
#  'CompetitionDistance': 250.0,
#  'Promo2': 1,
#  'Store': 68,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe023a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1130.0,
#  'Promo2': 1,
#  'Store': 69,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe023b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4840.0,
#  'Promo2': 0,
#  'Store': 70,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe023c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 17500.0,
#  'Promo2': 1,
#  'Store': 71,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe023d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2200.0,
#  'Promo2': 1,
#  'Store': 72,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe023e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1650.0,
#  'Promo2': 0,
#  'Store': 73,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe023f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 330.0,
#  'Promo2': 0,
#  'Store': 74,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0240')}
# {'Assortment': 'c',
#  'CompetitionDistance': 22440.0,
#  'Promo2': 0,
#  'Store': 75,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0241')}
# {'Assortment': 'c',
#  'CompetitionDistance': 19960.0,
#  'Promo2': 0,
#  'Store': 76,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0242')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1090.0,
#  'Promo2': 1,
#  'Store': 77,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0243')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3510.0,
#  'Promo2': 1,
#  'Store': 78,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0244')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3320.0,
#  'Promo2': 0,
#  'Store': 79,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0245')}
# {'Assortment': 'a',
#  'CompetitionDistance': 7910.0,
#  'Promo2': 0,
#  'Store': 80,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0246')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2370.0,
#  'Promo2': 1,
#  'Store': 81,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0247')}
# {'Assortment': 'a',
#  'CompetitionDistance': 22390.0,
#  'Promo2': 1,
#  'Store': 82,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0248')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2710.0,
#  'Promo2': 0,
#  'Store': 83,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0249')}
# {'Assortment': 'c',
#  'CompetitionDistance': 11810.0,
#  'Promo2': 0,
#  'Store': 84,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe024a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1870.0,
#  'Promo2': 0,
#  'Store': 85,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe024b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 480.0,
#  'Promo2': 1,
#  'Store': 86,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe024c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 560.0,
#  'Promo2': 0,
#  'Store': 87,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe024d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 10690.0,
#  'Promo2': 0,
#  'Store': 88,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe024e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2380.0,
#  'Promo2': 1,
#  'Store': 89,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe024f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 330.0,
#  'Promo2': 0,
#  'Store': 90,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0250')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2410.0,
#  'Promo2': 1,
#  'Store': 91,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0251')}
# {'Assortment': 'a',
#  'CompetitionDistance': 240.0,
#  'Promo2': 1,
#  'Store': 92,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0252')}
# {'Assortment': 'a',
#  'CompetitionDistance': 16690.0,
#  'Promo2': 1,
#  'Store': 93,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0253')}
# {'Assortment': 'c',
#  'CompetitionDistance': 14620.0,
#  'Promo2': 0,
#  'Store': 94,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0254')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1890.0,
#  'Promo2': 0,
#  'Store': 95,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0255')}
# {'Assortment': 'a',
#  'CompetitionDistance': 8780.0,
#  'Promo2': 1,
#  'Store': 96,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0256')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8980.0,
#  'Promo2': 0,
#  'Store': 97,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0257')}
# {'Assortment': 'c',
#  'CompetitionDistance': 15140.0,
#  'Promo2': 1,
#  'Store': 98,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0258')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2030.0,
#  'Promo2': 1,
#  'Store': 99,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0259')}
# {'Assortment': 'a',
#  'CompetitionDistance': 17930.0,
#  'Promo2': 0,
#  'Store': 100,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe025a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2440.0,
#  'Promo2': 1,
#  'Store': 101,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe025b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 150.0,
#  'Promo2': 1,
#  'Store': 102,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe025c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5210.0,
#  'Promo2': 0,
#  'Store': 103,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe025d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 390.0,
#  'Promo2': 0,
#  'Store': 104,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe025e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6190.0,
#  'Promo2': 1,
#  'Store': 105,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe025f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1390.0,
#  'Promo2': 0,
#  'Store': 106,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0260')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1930.0,
#  'Promo2': 0,
#  'Store': 107,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0261')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2190.0,
#  'Promo2': 0,
#  'Store': 108,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0262')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3300.0,
#  'Promo2': 0,
#  'Store': 109,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0263')}
# {'Assortment': 'c',
#  'CompetitionDistance': 46590.0,
#  'Promo2': 0,
#  'Store': 110,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0264')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7890.0,
#  'Promo2': 1,
#  'Store': 111,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0265')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1630.0,
#  'Promo2': 0,
#  'Store': 112,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0266')}
# {'Assortment': 'c',
#  'CompetitionDistance': 20930.0,
#  'Promo2': 0,
#  'Store': 113,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0267')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4510.0,
#  'Promo2': 1,
#  'Store': 114,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0268')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5740.0,
#  'Promo2': 1,
#  'Store': 115,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0269')}
# {'Assortment': 'a',
#  'CompetitionDistance': 680.0,
#  'Promo2': 0,
#  'Store': 116,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe026a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3450.0,
#  'Promo2': 0,
#  'Store': 117,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe026b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3580.0,
#  'Promo2': 0,
#  'Store': 118,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe026c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2100.0,
#  'Promo2': 0,
#  'Store': 119,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe026d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2290.0,
#  'Promo2': 1,
#  'Store': 120,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe026e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3570.0,
#  'Promo2': 1,
#  'Store': 121,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe026f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 58260.0,
#  'Promo2': 0,
#  'Store': 122,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0270')}
# {'Assortment': 'a',
#  'CompetitionDistance': 16760.0,
#  'Promo2': 0,
#  'Store': 123,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0271')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1410.0,
#  'Promo2': 0,
#  'Store': 124,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0272')}
# {'Assortment': 'a',
#  'CompetitionDistance': 760.0,
#  'Promo2': 0,
#  'Store': 125,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0273')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3370.0,
#  'Promo2': 1,
#  'Store': 126,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0274')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1350.0,
#  'Promo2': 1,
#  'Store': 127,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0275')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2000.0,
#  'Promo2': 1,
#  'Store': 128,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0276')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2460.0,
#  'Promo2': 1,
#  'Store': 129,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0277')}
# {'Assortment': 'a',
#  'CompetitionDistance': 900.0,
#  'Promo2': 1,
#  'Store': 130,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0278')}
# {'Assortment': 'a',
#  'CompetitionDistance': 920.0,
#  'Promo2': 0,
#  'Store': 131,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0279')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1040.0,
#  'Promo2': 1,
#  'Store': 132,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe027a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 270.0,
#  'Promo2': 1,
#  'Store': 133,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe027b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1200.0,
#  'Promo2': 0,
#  'Store': 134,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe027c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5190.0,
#  'Promo2': 1,
#  'Store': 135,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe027d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2200.0,
#  'Promo2': 1,
#  'Store': 136,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe027e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1730.0,
#  'Promo2': 1,
#  'Store': 137,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe027f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 25360.0,
#  'Promo2': 0,
#  'Store': 138,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0280')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1700.0,
#  'Promo2': 1,
#  'Store': 139,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0281')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1090.0,
#  'Promo2': 1,
#  'Store': 140,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0282')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1540.0,
#  'Promo2': 1,
#  'Store': 141,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0283')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1090.0,
#  'Promo2': 0,
#  'Store': 142,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0284')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2930.0,
#  'Promo2': 0,
#  'Store': 143,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0285')}
# {'Assortment': 'c',
#  'CompetitionDistance': 16570.0,
#  'Promo2': 0,
#  'Store': 144,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0286')}
# {'Assortment': 'a',
#  'CompetitionDistance': 280.0,
#  'Promo2': 1,
#  'Store': 145,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0287')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8050.0,
#  'Promo2': 1,
#  'Store': 146,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0288')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8540.0,
#  'Promo2': 0,
#  'Store': 147,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0289')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2090.0,
#  'Promo2': 0,
#  'Store': 148,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe028a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2610.0,
#  'Promo2': 1,
#  'Store': 149,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe028b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 31830.0,
#  'Promo2': 0,
#  'Store': 150,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe028c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4360.0,
#  'Promo2': 0,
#  'Store': 151,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe028d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1780.0,
#  'Promo2': 0,
#  'Store': 152,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe028e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 16240.0,
#  'Promo2': 1,
#  'Store': 153,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe028f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 16420.0,
#  'Promo2': 0,
#  'Store': 154,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0290')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3050.0,
#  'Promo2': 1,
#  'Store': 155,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0291')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2020.0,
#  'Promo2': 1,
#  'Store': 156,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0292')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2950.0,
#  'Promo2': 0,
#  'Store': 157,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0293')}
# {'Assortment': 'c',
#  'CompetitionDistance': 11840.0,
#  'Promo2': 1,
#  'Store': 158,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0294')}
# {'Assortment': 'a',
#  'CompetitionDistance': 8530.0,
#  'Promo2': 0,
#  'Store': 159,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0295')}
# {'Assortment': 'c',
#  'CompetitionDistance': 17110.0,
#  'Promo2': 0,
#  'Store': 160,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0296')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2970.0,
#  'Promo2': 0,
#  'Store': 161,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0297')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5340.0,
#  'Promo2': 1,
#  'Store': 162,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0298')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1480.0,
#  'Promo2': 0,
#  'Store': 163,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0299')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1160.0,
#  'Promo2': 1,
#  'Store': 164,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe029a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3720.0,
#  'Promo2': 1,
#  'Store': 165,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe029b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 100.0,
#  'Promo2': 1,
#  'Store': 166,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe029c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 140.0,
#  'Promo2': 0,
#  'Store': 167,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe029d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 12540.0,
#  'Promo2': 0,
#  'Store': 168,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe029e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 980.0,
#  'Promo2': 1,
#  'Store': 169,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe029f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1070.0,
#  'Promo2': 1,
#  'Store': 170,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a0')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2640.0,
#  'Promo2': 0,
#  'Store': 171,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 110.0,
#  'Promo2': 1,
#  'Store': 172,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a2')}
# {'Assortment': 'a',
#  'CompetitionDistance': 350.0,
#  'Promo2': 0,
#  'Store': 173,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a3')}
# {'Assortment': 'a',
#  'CompetitionDistance': 13090.0,
#  'Promo2': 1,
#  'Store': 174,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a4')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4130.0,
#  'Promo2': 0,
#  'Store': 175,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02a5')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3770.0,
#  'Promo2': 0,
#  'Store': 176,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1250.0,
#  'Promo2': 1,
#  'Store': 177,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1710.0,
#  'Promo2': 0,
#  'Store': 178,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02a8')}
# {'Assortment': 'c',
#  'CompetitionDistance': 480.0,
#  'Promo2': 0,
#  'Store': 179,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02a9')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5800.0,
#  'Promo2': 0,
#  'Store': 180,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02aa')}
# {'Assortment': 'a',
#  'CompetitionDistance': 12610.0,
#  'Promo2': 1,
#  'Store': 181,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02ab')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1390.0,
#  'Promo2': 1,
#  'Store': 182,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02ac')}
# {'Assortment': 'a',
#  'CompetitionDistance': 9670.0,
#  'Promo2': 0,
#  'Store': 183,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02ad')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3560.0,
#  'Promo2': 0,
#  'Store': 184,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02ae')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1860.0,
#  'Promo2': 0,
#  'Store': 185,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02af')}
# {'Assortment': 'a',
#  'CompetitionDistance': 290.0,
#  'Promo2': 1,
#  'Store': 186,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b0')}
# {'Assortment': 'c',
#  'CompetitionDistance': 19360.0,
#  'Promo2': 0,
#  'Store': 187,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 850.0,
#  'Promo2': 1,
#  'Store': 188,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02b2')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5760.0,
#  'Promo2': 0,
#  'Store': 189,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02b3')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1470.0,
#  'Promo2': 1,
#  'Store': 190,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b4')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1100.0,
#  'Promo2': 1,
#  'Store': 191,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b5')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2770.0,
#  'Promo2': 1,
#  'Store': 192,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02b6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 520.0,
#  'Promo2': 0,
#  'Store': 193,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b7')}
# {'Assortment': 'c',
#  'CompetitionDistance': 16970.0,
#  'Promo2': 1,
#  'Store': 194,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02b8')}
# {'Assortment': 'c',
#  'CompetitionDistance': 220.0,
#  'Promo2': 0,
#  'Store': 195,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02b9')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3850.0,
#  'Promo2': 1,
#  'Store': 196,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02ba')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4210.0,
#  'Promo2': 0,
#  'Store': 197,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02bb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 290.0,
#  'Promo2': 1,
#  'Store': 198,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02bc')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6360.0,
#  'Promo2': 1,
#  'Store': 199,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02bd')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1650.0,
#  'Promo2': 0,
#  'Store': 200,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02be')}
# {'Assortment': 'a',
#  'CompetitionDistance': 20260.0,
#  'Promo2': 1,
#  'Store': 201,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02bf')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5140.0,
#  'Promo2': 0,
#  'Store': 202,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02c0')}
# {'Assortment': 'c',
#  'CompetitionDistance': 490.0,
#  'Promo2': 0,
#  'Store': 203,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02c1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5630.0,
#  'Promo2': 1,
#  'Store': 204,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c2')}
# {'Assortment': 'a',
#  'CompetitionDistance': 110.0,
#  'Promo2': 0,
#  'Store': 205,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c3')}
# {'Assortment': 'c',
#  'CompetitionDistance': 380.0,
#  'Promo2': 1,
#  'Store': 206,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c4')}
# {'Assortment': 'a',
#  'CompetitionDistance': 6870.0,
#  'Promo2': 0,
#  'Store': 207,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c5')}
# {'Assortment': 'a',
#  'CompetitionDistance': 300.0,
#  'Promo2': 0,
#  'Store': 208,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02c6')}
# {'Assortment': 'c',
#  'CompetitionDistance': 11680.0,
#  'Promo2': 1,
#  'Store': 209,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 970.0,
#  'Promo2': 1,
#  'Store': 210,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02c8')}
# {'Assortment': 'c',
#  'CompetitionDistance': 350.0,
#  'Promo2': 0,
#  'Store': 211,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02c9')}
# {'Assortment': 'c',
#  'CompetitionDistance': 15050.0,
#  'Promo2': 0,
#  'Store': 212,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02ca')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4030.0,
#  'Promo2': 1,
#  'Store': 213,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02cb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 8650.0,
#  'Promo2': 1,
#  'Store': 214,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02cc')}
# {'Assortment': 'a',
#  'CompetitionDistance': 150.0,
#  'Promo2': 1,
#  'Store': 215,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02cd')}
# {'Assortment': 'a',
#  'CompetitionDistance': 190.0,
#  'Promo2': 1,
#  'Store': 216,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02ce')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3150.0,
#  'Promo2': 0,
#  'Store': 217,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02cf')}
# {'Assortment': 'c',
#  'CompetitionDistance': 640.0,
#  'Promo2': 1,
#  'Store': 218,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d0')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1640.0,
#  'Promo2': 0,
#  'Store': 219,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1000.0,
#  'Promo2': 0,
#  'Store': 220,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d2')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13530.0,
#  'Promo2': 0,
#  'Store': 221,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02d3')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2170.0,
#  'Promo2': 0,
#  'Store': 222,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d4')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2920.0,
#  'Promo2': 1,
#  'Store': 223,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02d5')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7930.0,
#  'Promo2': 1,
#  'Store': 224,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02d6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 10180.0,
#  'Promo2': 0,
#  'Store': 225,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02d7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 450.0,
#  'Promo2': 0,
#  'Store': 226,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d8')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2370.0,
#  'Promo2': 0,
#  'Store': 227,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02d9')}
# {'Assortment': 'c',
#  'CompetitionDistance': 10800.0,
#  'Promo2': 1,
#  'Store': 228,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02da')}
# {'Assortment': 'c',
#  'CompetitionDistance': 17410.0,
#  'Promo2': 1,
#  'Store': 229,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02db')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6680.0,
#  'Promo2': 0,
#  'Store': 230,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02dc')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3840.0,
#  'Promo2': 1,
#  'Store': 231,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02dd')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13570.0,
#  'Promo2': 1,
#  'Store': 232,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02de')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1890.0,
#  'Promo2': 0,
#  'Store': 233,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02df')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4370.0,
#  'Promo2': 0,
#  'Store': 234,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02e0')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5710.0,
#  'Promo2': 1,
#  'Store': 235,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1000.0,
#  'Promo2': 0,
#  'Store': 236,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e2')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1420.0,
#  'Promo2': 0,
#  'Store': 237,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e3')}
# {'Assortment': 'a',
#  'CompetitionDistance': 320.0,
#  'Promo2': 1,
#  'Store': 238,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e4')}
# {'Assortment': 'c',
#  'CompetitionDistance': 610.0,
#  'Promo2': 0,
#  'Store': 239,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02e5')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1110.0,
#  'Promo2': 0,
#  'Store': 240,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e6')}
# {'Assortment': 'c',
#  'CompetitionDistance': 780.0,
#  'Promo2': 0,
#  'Store': 241,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02e7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 6880.0,
#  'Promo2': 1,
#  'Store': 242,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02e8')}
# {'Assortment': 'a',
#  'CompetitionDistance': 310.0,
#  'Promo2': 1,
#  'Store': 243,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02e9')}
# {'Assortment': 'a',
#  'CompetitionDistance': 710.0,
#  'Promo2': 1,
#  'Store': 244,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02ea')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1310.0,
#  'Promo2': 0,
#  'Store': 245,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02eb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4660.0,
#  'Promo2': 0,
#  'Store': 246,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02ec')}
# {'Assortment': 'c',
#  'CompetitionDistance': 70.0,
#  'Promo2': 1,
#  'Store': 247,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02ed')}
# {'Assortment': 'c',
#  'CompetitionDistance': 340.0,
#  'Promo2': 1,
#  'Store': 248,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02ee')}
# {'Assortment': 'c',
#  'CompetitionDistance': 18010.0,
#  'Promo2': 0,
#  'Store': 249,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02ef')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3520.0,
#  'Promo2': 1,
#  'Store': 250,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02f0')}
# {'Assortment': 'c',
#  'CompetitionDistance': 340.0,
#  'Promo2': 0,
#  'Store': 251,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02f1')}
# {'Assortment': 'c',
#  'CompetitionDistance': 22330.0,
#  'Promo2': 1,
#  'Store': 252,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02f2')}
# {'Assortment': 'c',
#  'CompetitionDistance': 250.0,
#  'Promo2': 1,
#  'Store': 253,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02f3')}
# {'Assortment': 'a',
#  'CompetitionDistance': 330.0,
#  'Promo2': 1,
#  'Store': 254,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02f4')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4630.0,
#  'Promo2': 1,
#  'Store': 255,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe02f5')}
# {'Assortment': 'c',
#  'CompetitionDistance': 80.0,
#  'Promo2': 1,
#  'Store': 256,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02f6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 420.0,
#  'Promo2': 0,
#  'Store': 257,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02f7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 27190.0,
#  'Promo2': 1,
#  'Store': 258,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02f8')}
# {'Assortment': 'b',
#  'CompetitionDistance': 210.0,
#  'Promo2': 0,
#  'Store': 259,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe02f9')}
# {'Assortment': 'a',
#  'CompetitionDistance': 540.0,
#  'Promo2': 0,
#  'Store': 260,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02fa')}
# {'Assortment': 'c',
#  'CompetitionDistance': 15340.0,
#  'Promo2': 1,
#  'Store': 261,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe02fb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1180.0,
#  'Promo2': 0,
#  'Store': 262,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe02fc')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1140.0,
#  'Promo2': 1,
#  'Store': 263,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02fd')}
# {'Assortment': 'a',
#  'CompetitionDistance': 180.0,
#  'Promo2': 0,
#  'Store': 264,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02fe')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4580.0,
#  'Promo2': 1,
#  'Store': 265,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe02ff')}
# {'Assortment': 'c',
#  'CompetitionDistance': 360.0,
#  'Promo2': 1,
#  'Store': 266,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0300')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2460.0,
#  'Promo2': 0,
#  'Store': 267,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0301')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4520.0,
#  'Promo2': 0,
#  'Store': 268,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0302')}
# {'Assortment': 'c',
#  'CompetitionDistance': 60.0,
#  'Promo2': 0,
#  'Store': 269,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0303')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1450.0,
#  'Promo2': 0,
#  'Store': 270,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0304')}
# {'Assortment': 'a',
#  'CompetitionDistance': 420.0,
#  'Promo2': 1,
#  'Store': 271,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0305')}
# {'Assortment': 'a',
#  'CompetitionDistance': 16180.0,
#  'Promo2': 1,
#  'Store': 272,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0306')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8480.0,
#  'Promo2': 0,
#  'Store': 273,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0307')}
# {'Assortment': 'b',
#  'CompetitionDistance': 3640.0,
#  'Promo2': 1,
#  'Store': 274,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe0308')}
# {'Assortment': 'a',
#  'CompetitionDistance': 300.0,
#  'Promo2': 1,
#  'Store': 275,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0309')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2960.0,
#  'Promo2': 1,
#  'Store': 276,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe030a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 7840.0,
#  'Promo2': 1,
#  'Store': 277,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe030b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9260.0,
#  'Promo2': 0,
#  'Store': 278,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe030c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2320.0,
#  'Promo2': 1,
#  'Store': 279,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe030d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 18640.0,
#  'Promo2': 1,
#  'Store': 280,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe030e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6970.0,
#  'Promo2': 0,
#  'Store': 281,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe030f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1220.0,
#  'Promo2': 0,
#  'Store': 282,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0310')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2260.0,
#  'Promo2': 1,
#  'Store': 283,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0311')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1290.0,
#  'Promo2': 1,
#  'Store': 284,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0312')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2410.0,
#  'Promo2': 0,
#  'Store': 285,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0313')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1460.0,
#  'Promo2': 0,
#  'Store': 286,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0314')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2740.0,
#  'Promo2': 1,
#  'Store': 287,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0315')}
# {'Assortment': 'a',
#  'CompetitionDistance': 800.0,
#  'Promo2': 1,
#  'Store': 288,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0316')}
# {'Assortment': 'a',
#  'CompetitionDistance': 6540.0,
#  'Promo2': 0,
#  'Store': 289,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0317')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4150.0,
#  'Promo2': 0,
#  'Store': 290,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0318')}
# {'Assortment': 'a',
#  'CompetitionDistance': 100000.0,
#  'Promo2': 0,
#  'Store': 291,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0319')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1100.0,
#  'Promo2': 0,
#  'Store': 292,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe031a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 140.0,
#  'Promo2': 0,
#  'Store': 293,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe031b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3150.0,
#  'Promo2': 0,
#  'Store': 294,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe031c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 210.0,
#  'Promo2': 1,
#  'Store': 295,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe031d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 9580.0,
#  'Promo2': 1,
#  'Store': 296,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe031e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2300.0,
#  'Promo2': 0,
#  'Store': 297,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe031f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 19840.0,
#  'Promo2': 0,
#  'Store': 298,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0320')}
# {'Assortment': 'c',
#  'CompetitionDistance': 38630.0,
#  'Promo2': 0,
#  'Store': 299,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0321')}
# {'Assortment': 'c',
#  'CompetitionDistance': 120.0,
#  'Promo2': 1,
#  'Store': 300,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0322')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4510.0,
#  'Promo2': 0,
#  'Store': 301,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0323')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2190.0,
#  'Promo2': 1,
#  'Store': 302,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0324')}
# {'Assortment': 'a',
#  'CompetitionDistance': 15430.0,
#  'Promo2': 1,
#  'Store': 303,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0325')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1950.0,
#  'Promo2': 0,
#  'Store': 304,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0326')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2470.0,
#  'Promo2': 1,
#  'Store': 305,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0327')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5100.0,
#  'Promo2': 1,
#  'Store': 306,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0328')}
# {'Assortment': 'a',
#  'CompetitionDistance': 18660.0,
#  'Promo2': 0,
#  'Store': 307,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0329')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1070.0,
#  'Promo2': 1,
#  'Store': 308,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe032a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 8740.0,
#  'Promo2': 1,
#  'Store': 309,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe032b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2290.0,
#  'Promo2': 1,
#  'Store': 310,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe032c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 680.0,
#  'Promo2': 0,
#  'Store': 311,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe032d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 11300.0,
#  'Promo2': 0,
#  'Store': 312,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe032e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 14160.0,
#  'Promo2': 0,
#  'Store': 313,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe032f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3560.0,
#  'Promo2': 1,
#  'Store': 314,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0330')}
# {'Assortment': 'c',
#  'CompetitionDistance': 38710.0,
#  'Promo2': 0,
#  'Store': 315,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0331')}
# {'Assortment': 'a',
#  'CompetitionDistance': 9000.0,
#  'Promo2': 0,
#  'Store': 316,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0332')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3140.0,
#  'Promo2': 1,
#  'Store': 317,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0333')}
# {'Assortment': 'c',
#  'CompetitionDistance': 32330.0,
#  'Promo2': 0,
#  'Store': 318,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0334')}
# {'Assortment': 'c',
#  'CompetitionDistance': 570.0,
#  'Promo2': 1,
#  'Store': 319,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0335')}
# {'Assortment': 'c',
#  'CompetitionDistance': 210.0,
#  'Promo2': 0,
#  'Store': 320,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0336')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8140.0,
#  'Promo2': 1,
#  'Store': 321,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0337')}
# {'Assortment': 'a',
#  'CompetitionDistance': 17500.0,
#  'Promo2': 1,
#  'Store': 322,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0338')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8400.0,
#  'Promo2': 1,
#  'Store': 323,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0339')}
# {'Assortment': 'a',
#  'CompetitionDistance': 13140.0,
#  'Promo2': 1,
#  'Store': 324,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe033a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 350.0,
#  'Promo2': 1,
#  'Store': 325,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe033b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 10070.0,
#  'Promo2': 1,
#  'Store': 326,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe033c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1390.0,
#  'Promo2': 0,
#  'Store': 327,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe033d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3130.0,
#  'Promo2': 0,
#  'Store': 328,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe033e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1310.0,
#  'Promo2': 1,
#  'Store': 329,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe033f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 370.0,
#  'Promo2': 1,
#  'Store': 330,
#  'StoreType': 'a',
# ...
# {'Assortment': 'c',
#  'CompetitionDistance': 4180.0,
#  'Promo2': 0,
#  'Store': 1007,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05e5')}
# {'Assortment': 'c',
#  'CompetitionDistance': 30.0,
#  'Promo2': 0,
#  'Store': 1008,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05e6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 230.0,
#  'Promo2': 1,
#  'Store': 1009,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05e7')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4610.0,
#  'Promo2': 1,
#  'Store': 1010,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05e8')}
# {'Assortment': 'c',
#  'CompetitionDistance': 490.0,
#  'Promo2': 1,
#  'Store': 1011,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05e9')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6330.0,
#  'Promo2': 1,
#  'Store': 1012,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05ea')}
# {'Assortment': 'a',
#  'CompetitionDistance': 630.0,
#  'Promo2': 1,
#  'Store': 1013,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05eb')}
# {'Assortment': 'c',
#  'CompetitionDistance': 210.0,
#  'Promo2': 1,
#  'Store': 1014,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05ec')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9910.0,
#  'Promo2': 1,
#  'Store': 1015,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05ed')}
# {'Assortment': 'c',
#  'CompetitionDistance': 550.0,
#  'Promo2': 1,
#  'Store': 1016,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05ee')}
# {'Assortment': 'a',
#  'CompetitionDistance': 110.0,
#  'Promo2': 0,
#  'Store': 1017,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05ef')}
# {'Assortment': 'c',
#  'CompetitionDistance': 140.0,
#  'Promo2': 0,
#  'Store': 1018,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05f0')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2740.0,
#  'Promo2': 1,
#  'Store': 1019,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05f1')}
# {'Assortment': 'a',
#  'CompetitionDistance': 40.0,
#  'Promo2': 0,
#  'Store': 1020,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05f2')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1080.0,
#  'Promo2': 0,
#  'Store': 1021,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05f3')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1520.0,
#  'Promo2': 0,
#  'Store': 1022,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05f4')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3740.0,
#  'Promo2': 1,
#  'Store': 1023,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05f5')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1990.0,
#  'Promo2': 0,
#  'Store': 1024,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05f6')}
# {'Assortment': 'a',
#  'CompetitionDistance': 720.0,
#  'Promo2': 0,
#  'Store': 1025,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05f7')}
# {'Assortment': 'a',
#  'CompetitionDistance': 450.0,
#  'Promo2': 1,
#  'Store': 1026,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe05f8')}
# {'Assortment': 'c',
#  'CompetitionDistance': 190.0,
#  'Promo2': 1,
#  'Store': 1027,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05f9')}
# {'Assortment': 'a',
#  'CompetitionDistance': 150.0,
#  'Promo2': 1,
#  'Store': 1028,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05fa')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1590.0,
#  'Promo2': 0,
#  'Store': 1029,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05fb')}
# {'Assortment': 'a',
#  'CompetitionDistance': 36410.0,
#  'Promo2': 0,
#  'Store': 1030,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05fc')}
# {'Assortment': 'a',
#  'CompetitionDistance': 590.0,
#  'Promo2': 0,
#  'Store': 1031,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05fd')}
# {'Assortment': 'c',
#  'CompetitionDistance': 270.0,
#  'Promo2': 1,
#  'Store': 1032,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe05fe')}
# {'Assortment': 'a',
#  'CompetitionDistance': 7680.0,
#  'Promo2': 0,
#  'Store': 1033,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe05ff')}
# {'Assortment': 'a',
#  'CompetitionDistance': 13750.0,
#  'Promo2': 0,
#  'Store': 1034,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0600')}
# {'Assortment': 'a',
#  'CompetitionDistance': 27150.0,
#  'Promo2': 0,
#  'Store': 1035,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0601')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9560.0,
#  'Promo2': 1,
#  'Store': 1036,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0602')}
# {'Assortment': 'c',
#  'CompetitionDistance': 150.0,
#  'Promo2': 0,
#  'Store': 1037,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0603')}
# {'Assortment': 'a',
#  'CompetitionDistance': 17290.0,
#  'Promo2': 0,
#  'Store': 1038,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0604')}
# {'Assortment': 'c',
#  'CompetitionDistance': 70.0,
#  'Promo2': 1,
#  'Store': 1039,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0605')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4030.0,
#  'Promo2': 1,
#  'Store': 1040,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0606')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1600.0,
#  'Promo2': 1,
#  'Store': 1041,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0607')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3440.0,
#  'Promo2': 1,
#  'Store': 1042,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0608')}
# {'Assortment': 'a',
#  'CompetitionDistance': 420.0,
#  'Promo2': 0,
#  'Store': 1043,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0609')}
# {'Assortment': 'a',
#  'CompetitionDistance': 240.0,
#  'Promo2': 1,
#  'Store': 1044,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe060a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 26990.0,
#  'Promo2': 0,
#  'Store': 1045,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe060b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 29070.0,
#  'Promo2': 0,
#  'Store': 1046,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe060c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3750.0,
#  'Promo2': 1,
#  'Store': 1047,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe060d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1860.0,
#  'Promo2': 1,
#  'Store': 1048,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe060e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 370.0,
#  'Promo2': 1,
#  'Store': 1049,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe060f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13170.0,
#  'Promo2': 1,
#  'Store': 1050,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0610')}
# {'Assortment': 'a',
#  'CompetitionDistance': 200.0,
#  'Promo2': 1,
#  'Store': 1051,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0611')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5080.0,
#  'Promo2': 1,
#  'Store': 1052,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0612')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1710.0,
#  'Promo2': 0,
#  'Store': 1053,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0613')}
# {'Assortment': 'c',
#  'CompetitionDistance': 13190.0,
#  'Promo2': 1,
#  'Store': 1054,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0614')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1980.0,
#  'Promo2': 0,
#  'Store': 1055,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0615')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5350.0,
#  'Promo2': 1,
#  'Store': 1056,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0616')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3230.0,
#  'Promo2': 0,
#  'Store': 1057,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0617')}
# {'Assortment': 'c',
#  'CompetitionDistance': 180.0,
#  'Promo2': 1,
#  'Store': 1058,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0618')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3380.0,
#  'Promo2': 0,
#  'Store': 1059,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0619')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3430.0,
#  'Promo2': 1,
#  'Store': 1060,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe061a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 8110.0,
#  'Promo2': 0,
#  'Store': 1061,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe061b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 190.0,
#  'Promo2': 1,
#  'Store': 1062,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe061c')}
# {'Assortment': 'c',
#  'CompetitionDistance': 6250.0,
#  'Promo2': 0,
#  'Store': 1063,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe061d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 420.0,
#  'Promo2': 0,
#  'Store': 1064,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe061e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1290.0,
#  'Promo2': 1,
#  'Store': 1065,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe061f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3350.0,
#  'Promo2': 0,
#  'Store': 1066,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0620')}
# {'Assortment': 'c',
#  'CompetitionDistance': 12020.0,
#  'Promo2': 0,
#  'Store': 1067,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0621')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5010.0,
#  'Promo2': 1,
#  'Store': 1068,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0622')}
# {'Assortment': 'c',
#  'CompetitionDistance': 18050.0,
#  'Promo2': 1,
#  'Store': 1069,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0623')}
# {'Assortment': 'c',
#  'CompetitionDistance': 400.0,
#  'Promo2': 0,
#  'Store': 1070,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0624')}
# {'Assortment': 'a',
#  'CompetitionDistance': 820.0,
#  'Promo2': 1,
#  'Store': 1071,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0625')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5380.0,
#  'Promo2': 1,
#  'Store': 1072,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0626')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1710.0,
#  'Promo2': 1,
#  'Store': 1073,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0627')}
# {'Assortment': 'c',
#  'CompetitionDistance': 3330.0,
#  'Promo2': 1,
#  'Store': 1074,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0628')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1410.0,
#  'Promo2': 0,
#  'Store': 1075,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0629')}
# {'Assortment': 'c',
#  'CompetitionDistance': 90.0,
#  'Promo2': 1,
#  'Store': 1076,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe062a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3750.0,
#  'Promo2': 1,
#  'Store': 1077,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe062b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 670.0,
#  'Promo2': 1,
#  'Store': 1078,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe062c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 16680.0,
#  'Promo2': 1,
#  'Store': 1079,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe062d')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2410.0,
#  'Promo2': 1,
#  'Store': 1080,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe062e')}
# {'Assortment': 'a',
#  'CompetitionDistance': 400.0,
#  'Promo2': 0,
#  'Store': 1081,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe062f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 440.0,
#  'Promo2': 0,
#  'Store': 1082,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0630')}
# {'Assortment': 'c',
#  'CompetitionDistance': 11540.0,
#  'Promo2': 1,
#  'Store': 1083,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0631')}
# {'Assortment': 'a',
#  'CompetitionDistance': 190.0,
#  'Promo2': 1,
#  'Store': 1084,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0632')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4030.0,
#  'Promo2': 0,
#  'Store': 1085,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0633')}
# {'Assortment': 'a',
#  'CompetitionDistance': 180.0,
#  'Promo2': 1,
#  'Store': 1086,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0634')}
# {'Assortment': 'c',
#  'CompetitionDistance': 2210.0,
#  'Promo2': 0,
#  'Store': 1087,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0635')}
# {'Assortment': 'a',
#  'CompetitionDistance': 4300.0,
#  'Promo2': 1,
#  'Store': 1088,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0636')}
# {'Assortment': 'a',
#  'CompetitionDistance': 5220.0,
#  'Promo2': 0,
#  'Store': 1089,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0637')}
# {'Assortment': 'a',
#  'CompetitionDistance': 330.0,
#  'Promo2': 1,
#  'Store': 1090,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0638')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9990.0,
#  'Promo2': 0,
#  'Store': 1091,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0639')}
# {'Assortment': 'a',
#  'CompetitionDistance': 300.0,
#  'Promo2': 1,
#  'Store': 1092,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe063a')}
# {'Assortment': 'c',
#  'CompetitionDistance': 10450.0,
#  'Promo2': 0,
#  'Store': 1093,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe063b')}
# {'Assortment': 'a',
#  'CompetitionDistance': 2380.0,
#  'Promo2': 1,
#  'Store': 1094,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe063c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 690.0,
#  'Promo2': 1,
#  'Store': 1095,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe063d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1130.0,
#  'Promo2': 1,
#  'Store': 1096,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe063e')}
# {'Assortment': 'b',
#  'CompetitionDistance': 720.0,
#  'Promo2': 0,
#  'Store': 1097,
#  'StoreType': 'b',
#  '_id': ObjectId('653d56d882e382e525fe063f')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1830.0,
#  'Promo2': 0,
#  'Store': 1098,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0640')}
# {'Assortment': 'c',
#  'CompetitionDistance': 200.0,
#  'Promo2': 1,
#  'Store': 1099,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0641')}
# {'Assortment': 'a',
#  'CompetitionDistance': 540.0,
#  'Promo2': 1,
#  'Store': 1100,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0642')}
# {'Assortment': 'c',
#  'CompetitionDistance': 4060.0,
#  'Promo2': 0,
#  'Store': 1101,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0643')}
# {'Assortment': 'a',
#  'CompetitionDistance': 850.0,
#  'Promo2': 1,
#  'Store': 1102,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0644')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1340.0,
#  'Promo2': 1,
#  'Store': 1103,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0645')}
# {'Assortment': 'a',
#  'CompetitionDistance': 260.0,
#  'Promo2': 1,
#  'Store': 1104,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0646')}
# {'Assortment': 'c',
#  'CompetitionDistance': 330.0,
#  'Promo2': 1,
#  'Store': 1105,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe0647')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5330.0,
#  'Promo2': 1,
#  'Store': 1106,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0648')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1400.0,
#  'Promo2': 1,
#  'Store': 1107,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0649')}
# {'Assortment': 'a',
#  'CompetitionDistance': 540.0,
#  'Promo2': 0,
#  'Store': 1108,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe064a')}
# {'Assortment': 'a',
#  'CompetitionDistance': 3490.0,
#  'Promo2': 1,
#  'Store': 1109,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe064b')}
# {'Assortment': 'c',
#  'CompetitionDistance': 900.0,
#  'Promo2': 0,
#  'Store': 1110,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe064c')}
# {'Assortment': 'a',
#  'CompetitionDistance': 1900.0,
#  'Promo2': 1,
#  'Store': 1111,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe064d')}
# {'Assortment': 'c',
#  'CompetitionDistance': 1880.0,
#  'Promo2': 0,
#  'Store': 1112,
#  'StoreType': 'c',
#  '_id': ObjectId('653d56d882e382e525fe064e')}
# {'Assortment': 'c',
#  'CompetitionDistance': 9260.0,
#  'Promo2': 0,
#  'Store': 1113,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe064f')}
# {'Assortment': 'c',
#  'CompetitionDistance': 870.0,
#  'Promo2': 0,
#  'Store': 1114,
#  'StoreType': 'a',
#  '_id': ObjectId('653d56d882e382e525fe0650')}
# {'Assortment': 'c',
#  'CompetitionDistance': 5350.0,
#  'Promo2': 1,
#  'Store': 1115,
#  'StoreType': 'd',
#  '_id': ObjectId('653d56d882e382e525fe0651')}

# %% [markdown]
# # Ideias para o conjunto de treino

# %%
final_dic['train'].head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
final_dic['train'].dtypes
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %% [markdown]
# Variáveis Binárias: Irão continuar da mesma foram.
#
# Variáveis categóricas: Store. Ideia interessante é colocar a média do mês naquele ano, para a loja, e a média dos dias das semana no mesmo ano.
#
# Variáveis Data: Tratamento ainda não identificado.
#
#
# Assim, precisamos construir algumas coleções auxiliares:
#
# Média da loja no ano anterior
#
# Mas de qualquer jeito, devemos adicionar o conjunto de dados de treino ao nosso banco de dados

# %%
# Adiciona a coluna ANO-MES
df = final_dic['train'].copy()
df.loc[:,"YearMonth"] = df['Date'].str.slice(0,7)

df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday YearMonth
# 0              1   2015-07
# 1              1   2015-07
# 2              1   2015-07
# 3              1   2015-07
# 4              1   2015-07

# %%
store_collections = []

for store_id in df['Store'].unique():
    
    stores = db.get_collection(f"Store-{store_id}")
    store_collections.append(stores)

# %%
columns = df.columns

rows,cols = df.shape

for store_id in df['Store'].unique():

    # O que será inserido.
    main_fdata = []
    
    df_aux = df[df['Store'] == store_id] # Linhas que são da loja com ID store_id
    
    for index, row in df_aux.iterrows():
            fdata = {}
            for i in range(cols):
                    fdata[columns[i]] = row[columns[i]]
            main_fdata.append(fdata)
    with timeout(100):
        store_collections[store_id-1].insert_many(main_fdata)

# %%
# Query com pymongo
def get_document(q_param,col):
    return col.find(q_param)[0]

# %%
get_document({},store_collections[1114])
# Out:
# {'_id': ObjectId('653d671fd8c617e0a8724f96'),
#  'Store': 1115,
#  'DayOfWeek': 5,
#  'Date': '2015-07-31',
#  'Sales': 8680,
#  'Customers': 538,
#  'Open': 1,
#  'Promo': 1,
#  'StateHoliday': '0',
#  'SchoolHoliday': 1,
#  'YearMonth': '2015-07'}

# %%
"""
q_param = {"Store":1,"Date":{'$regex':"^2013.*$"}}
get_document(q_param,train)"""
# Out:
# '\nq_param = {"Store":1,"Date":{\'$regex\':"^2013.*$"}}\nget_document(q_param,train)'

# %%
store_mean_collections = []

for store_id in df['Store'].unique():
    
    stores = db.get_collection(f"Store_{store_id}_Means")
    store_mean_collections.append(stores)

# %%
store_WD_collections = []

for store_id in df['Store'].unique():
    
    stores = db.get_collection(f"WD_{store_id}_Means")
    store_WD_collections.append(stores)

# %%
for index,collection in enumerate(store_mean_collections):

    store_mean_collections[index].insert_many(store_collections[index].aggregate([

    {"$group": {
        "_id": {
            "YearMonth": "$YearMonth"
            },
    
        "media": {
            "$avg": "$Sales" 
            }
        
        }  
    }
]))

# %%
get_document({},store_mean_collections[1113])
# Out:
# {'_id': {'YearMonth': '2013-12'}, 'media': 19464.516129032258}

# %%
for index,collection in enumerate(store_WD_collections):

    store_WD_collections[index].insert_many(store_collections[index].aggregate([

    {"$group": {
        "_id": {
            "YearMonth": "$YearMonth",
            "DayOfWeek": "$DayOfWeek"
            },
    
        "media": {
            "$avg": "$Sales" 
            } 
        }
    }
]))

# %%
get_document({},store_WD_collections[0])
# Out:
# {'_id': {'YearMonth': '2015-02', 'DayOfWeek': 4}, 'media': 4199.0}

# %% [markdown]
# Finalmente, temos todos os valores essenciais para construir nosso conjunto de dados de teste e de treino

# %% [markdown]
# ## Criando o dataset final

# %% [markdown]
# Nosso dataset de treino terá os seguintes atributos: Store_mean	DayOfWeek_mean	Date	Sales	Open	Promo	StateHoliday	SchoolHoliday.
#
# Dessa maneira, iremos construir o conjunto de dados realizando requisições nas coleções.
#
# Precisamos de linhas dessa forma:
#
# {Store_mean, DayOfWeek_mean, Date, Open, Promo, StateHoliday, SchollHoliday, Sales}

# %%
train_collections = []

for train_id in df['Store'].unique():
    
    stores = db.get_collection(f"Train-{train_id}")
    train_collections.append(stores)

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday YearMonth
# 0              1   2015-07
# 1              1   2015-07
# 2              1   2015-07
# 3              1   2015-07
# 4              1   2015-07

# %%
columns = df.columns
N = len(train_collections)
import time

t0 = time.time()

for index,colection in enumerate(train_collections):

    # O que será inserido.
    main_fdata = []
    
    df_aux = df[df['Store'] == index+1] # Linhas que são da loja com ID store_id
    
    for _, row in df_aux.iterrows():
            fdata = {}
            for i in range(cols):
                
                    if columns[i] not in ['Store','DayOfWeek','Customers','YearMonth']:
                        fdata[columns[i]] = row[columns[i]]
                    elif columns[i] not in ['Customers', 'YearMonth']:

                        if columns[i] == 'Store':
                            fdata[columns[i]] = get_document({'_id': {'YearMonth': row['YearMonth']}},store_mean_collections[row['Store']-1])['media']
                            
                        elif columns[i] == 'DayOfWeek':

                            fdata[columns[i]] = get_document({'_id': {'YearMonth': row['YearMonth'], 'DayOfWeek':row['DayOfWeek'] }},store_WD_collections[row['Store']-1])['media']
                        
                        
            main_fdata.append(fdata)

    
    with timeout(100):
        train_collections[index].insert_many(main_fdata)
        print(f"\r{index}/{N} ({(time.time()-t0):.3f} s)" , end=' ')
# Out:
# 1114/1115 (1428.084 s)

# %%
def collections_request(collection) :


    cursor = collection.find({})

    cursor = list(cursor) 
    df = pd.DataFrame(cursor).drop("_id",axis=1)

    return df

# %%
collections_request(train_collections[1000])
# Out:
#            Store  DayOfWeek        Date  Sales  Open  Promo StateHoliday  \
# 0    5018.064516    5936.60  2015-07-31   7724     1      1            0
# 1    5018.064516    5944.80  2015-07-30   6418     1      1            0
# 2    5018.064516    5947.40  2015-07-29   7005     1      1            0
# 3    5018.064516    6118.50  2015-07-28   7469     1      1            0
# 4    5018.064516    7020.75  2015-07-27   8806     1      1            0
# ..           ...        ...         ...    ...   ...    ...          ...
# 937  4157.838710    3176.50  2013-01-05   3264     1      0            0
# 938  4157.838710    5127.25  2013-01-04   4542     1      0            0
# 939  4157.838710    5228.20  2013-01-03   4123     1      0            0
# 940  4157.838710    4621.60  2013-01-02   4224     1      0            0
# 941  4157.838710    4441.40  2013-01-01      0     0      0            a
#
#      SchoolHoliday
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 937              0
# 938              1
# 939              1
# 940              1
# 941              1
#
# [942 rows x 8 columns]
